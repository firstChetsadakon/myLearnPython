# %% [markdown]
# <a href="https://colab.research.google.com/github/firstChetsadakon/myLearnPython/blob/inclass/Chetsadakon_Kongphasuk_of_%5BWeek13_lab%5D_data_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Visualization with Titanic data.
# Load the Titanic dataset from Seaborn and create a visualization to answer the following question.
#
# Q1) We want to compare how many people embark in each town.
#
# Q2) how different in terms of fare between males and females?
#
# Q3) Do we see more surviving people in females and the first class?
#
# Q4) Do we spot any fare difference compared to age and sex? Can we spot an outlier fares in the plot?
#
# Q5) We want to see the number of males and females in each age group(bin). (please set a bin step to 10. E.g. 0-10,10-20,20-30, ...)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
pd.set_option('display.max_columns', 20)
pd.set_option('display.width', 1000)

data = sns.load_dataset("titanic")
print(data)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class    who  adult_male deck  embark_town alive  alone
# 0           0       3    male  22.0      1      0   7.2500        S   Third    man        True  NaN  Southampton    no  False
# 1           1       1  female  38.0      1      0  71.2833        C   First  woman       False    C    Cherbourg   yes  False
# 2           1       3  female  26.0      0      0   7.9250        S   Third  woman       False  NaN  Southampton   yes   True
# 3           1       1  female  35.0      1      0  53.1000        S   First  woman       False    C  Southampton   yes  False
# 4           0       3    male  35.0      0      0   8.0500        S   Third    man        True  NaN  Southampton    no   True
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...    ...         ...  ...          ...   ...    ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second    man        True  NaN  Southampton    no   True
# 887         1       1  female  19.0      0      0  30.0000        S   First  woman       False    B  Southampton   yes   True
# 888         0       3  female   NaN      1      2  23.4500        S   Third  woman       False  NaN  Southampton    no  False
# 889         1       1    male  26.0      0      0  30.0000        C   First    man        True    C    Cherbourg   yes   True
# 890         0       3    male  32.0      0      0   7.7500        Q   Third    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
# Q1) We want to compare how many people embark in each town.
sns.countplot(data, x = 'embark_town')
# Out:
# <Axes: xlabel='embark_town', ylabel='count'>

# %%
# Q2) how different in terms of fare between males and females?
sns.barplot(data, x = 'sex', y = 'fare', color='green')
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
# Q3) Do we see more surviving people in females and the first class?

data = data.loc[(data['survived']== 1)]
              # data
sns.histplot(data=data, x="class", hue="sex", multiple="stack")
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='class', ylabel='Count'>

# %%
# Q4) Do we spot any fare difference compared to age and sex? Can we spot an outlier fares in the plot?
plt.figure(figsize=(12, 8))
sns.scatterplot(data=data, x='age', y='fare', hue='sex', palette=['blue', 'red'], alpha=0.6)

plt.title('Fare vs Age by Sex')
plt.xlabel('Age')
plt.ylabel('Fare')

# Add a legend
plt.legend(title='Sex')

# Show the plot
plt.show()

# %%
# Q5) We want to see the number of males and females in each age group(bin). (please set a bin step to 10. E.g. 0-10,10-20,20-30, ...)
sns.histplot(data, x='age', hue='sex', binwidth = 10, kde=True, multiple = 'stack')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='age', ylabel='Count'>
